# %%
# Add relevant Jupyter notebook extensions 
# %load_ext autoreload
# %autoreload 2

# %%
# You can double-check your Python path like this...
import sys  
print(sys.path)
# Out:
# ['/Users/benpaulwell/anaconda3/lib/python311.zip', '/Users/benpaulwell/anaconda3/lib/python3.11', '/Users/benpaulwell/anaconda3/lib/python3.11/lib-dynload', '', '/Users/benpaulwell/.venvs/first-assignment-venv/lib/python3.11/site-packages', '/Users/benpaulwell/Documents/B1 coding/b1-coding-practical-mt24-main']

# %% [markdown]
# # Simulate closed-loop
# After implementing your control functionality, you can simulate the closed-loop with code that looks something like this...

# %%
# Import relevant modules
from uuv_mission import Submarine
from uuv_mission import Mission
from uuv_mission import ClosedLoop
from control import PDController
sub = Submarine()               
# Instantiate your controller (depending on your implementation)
controller = PDController(kp=0.15, kd=0.6)
closed_loop = ClosedLoop(sub, controller)
mission = Mission.from_csv("/Users/benpaulwell/Documents/B1 coding/b1-coding-practical-mt24-main/data/mission.csv") # You must implement this method in the Mission class

trajectory = closed_loop.simulate_with_random_disturbances(mission)
trajectory.plot_completed_mission(mission)
